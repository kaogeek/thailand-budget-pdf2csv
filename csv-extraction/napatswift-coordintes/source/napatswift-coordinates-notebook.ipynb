# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from tqdm.auto import trange, tqdm
import re
import pandas as pd

def tn_to_arb(line):
  fline = ''
  for char in line:
    if ord(char) >= ord('๐') and ord(char) <= ord('๙'):
      fline += str(ord(char) - ord('๐'))
    else:
      fline += char
  return fline

def get_patern_of_bullet(String):
  regx = [('[1-9][0-9]*(\.[1-9][0-9]*)*\)$', 20),
   ('\(\d*(\.?\d*)*\)$', 50),
   ('[1-9][0-9]*(\.[1-9][0-9]*)+$', 2),
   ('[1-9][0-9]*\.$', 1),
   ('[1-9][0-9]*$', 30)]

  for r, l in regx:
    if re.match(r, String):
      if l in [2, 20, 50]:
        l = String.count('.') + l
      return r, l
  return 0

def mode(lst):
  if isinstance(lst, np.ndarray):
    lst = lst.tolist()
  return max(set(lst), key=lst.count)

# %%
def isthaichar(string):
    return len(string) - len([c for c in string if 3585 <= ord(c) < 3676])

# %%
def to_gregorian(input):
  if input:
    return int(input) - 543
  else:
    return input

# %%
class ThaiBudget:
  def __init__(self, json_path):
    with open(json_path) as json_file:
      self._data_ = json.load(json_file)
      self.docs = [ref_doc for ref_doc in self._data_]
  
  def get_doc(self, ref_doc):
    return Doc(self._data_[ref_doc], ref_doc)

# %%
class Doc:
  def page(self, num_page, true_num_page=False):
    if true_num_page:
      npage = num_page + self.start
      return Page(npage, self._raw_page[npage], num_page)
    else:
      return Page(num_page, self._raw_page[num_page])

  @property
  def index_page(self):
    id_pages = []
    for i in range(65):
      page = self.page(i).get_text_lines()
      if page != None:
        text = ''.join(page)
        if re.findall('\d+ (ถึง) \d+', text):
          id_pages.append(i)
        elif id_pages:
          break
    return id_pages

  @property
  def ministry(self):
    ministry = []
    lines = self.page(0)._lines(yPos=True)
    for tline, ypline in lines:
      if (np.array([1250, 1400]) < ypline).any() and (ypline < np.array([2000, 2100])).any():
        ministry.append(' '.join([tn_to_arb(block) for block in tline if block not in '*-']))
    return ministry

  @property
  def range(self):
    if self.ref_doc in ['2022.3.12', '2022.3.16(2)', '2022.3.16(3)']:
      ministry = []
      page_rage = []
      for ipage in self.index_page:
        ministry, page_rage_ = get_range_in_page(self.page(ipage), ministry)
        page_rage += page_rage_
      return page_rage
    page_rage = []
    ministry = ''
    tempdict = {}
    stw = [ministr[:int(len(ministr)*0.6)]for ministr in self.ministry]
    for i in self.index_page:
      page = self.page(i)
      page.dline_tolerance = 50
      lines = page.get_text_list_lines()
      for line in lines:
        if [sw for sw in stw if ' '.join(line).startswith(sw)]:
          ministry = [word for word in line if word != 'ถึง' and not word.isdigit() and word != 'หน้า']
          ministry = ' '.join(ministry)
        if re.match('\(\d+\)', line[0]):
          if tempdict:
            page_rage.append(tempdict)
            tempdict = {}
          tempdict['ministry'] = ministry
          tempdict['budget_unit'] = ' '.join([word for word in line[1:] if word != 'ถึง' and not word.isdigit()])
        
        if line[0] == 'สภากาชาดไทย':
          page_rage.append(tempdict)
          tempdict = {}
          tempdict['ministry'] = ministry
          tempdict['budget_unit'] = ministry
        if line[0] == 'ส่วนราชการในพระองค์':
          page_rage.append(tempdict)
          tempdict = {}
          tempdict['ministry'] = ministry
          tempdict['budget_unit'] = ministry
        if line[0] == 'งบกลาง':
          tempdict['ministry'] = ministry
          tempdict['budget_unit'] = ministry
          tempdict['range'] = (5, 8)
        if '7. ราย' in ' '.join(line) or 'ผลผลิต/โครงการ' in ' '.join(line):
          if line[-1].isdigit():
            start = line[-1]
        if '8. ราย' in ' '.join(line):          
          tempdict['range'] = (int(start), int(line[-1]))
          if self.ref_doc == '2022.3.13(1)':
            if tempdict['budget_unit'] == 'จังหวัดนราธิวาส':
              tempdict['range'] = (542, 552)
            elif tempdict['budget_unit'] =='กลุ่มจังหวัดภาคใต้ชายแดน':
              tempdict['range'] = (527, 535)
            elif tempdict['budget_unit'] =='จังหวัดฉะเชิงเทรา':
              tempdict['range'] = (604, 614)
            elif tempdict['budget_unit'] == 'จังหวัดจันทบุรี':
              tempdict['range'] = (680, 614)
            elif tempdict['budget_unit'] == 'จังหวัดตราด':
              tempdict['range'] = (699, 614)
    page_rage.append(tempdict)
    return page_rage

  @property
  def start(self):
    idpage = self.index_page
    fstpage = idpage[-1] + 1
    while self.page(fstpage).get_blocks() == None:
      fstpage += 1
    return fstpage - 1
  
  def get_budgetary_unit(self, minis):
    budumi = []
    for budu in self.range:
      if minis == budu['ministry']:
        budumi.append({'budget_unit': budu['budget_unit'],
                      'range': budu['range']})
      
    return budumi

  def get_ministry(self, budge_u):
    for budu in self.range:
      if budge_u == budu['budget_unit']:
        return {'ministry': budu['ministry'],
                      'range': budu['range']}
      else:
        return None

  def __init__(self, raw_pages, ref_doc):
    self.fiscal_year, self.chabab, self.lem = ref_doc.split('.')
    self._raw_page = raw_pages
    self.ref_doc = ref_doc
    self.len = len(raw_pages)

# %%
class Page:
  def get_blocks(self):
    if self._page == []:
      return None
    blocks = []
    for block in self._page:
      crd = self._simplify_coordinates([[coo['x'], coo['y']] for coo in block['vertices']])
      blocks.append({'text': block['description'],
                    'sim_coord': crd})
    return blocks

  @property
  def xSigPos(self):
    w = self.whpage[0][1] - self.whpage[0][0]
    for line in self.Lines:
      text = [block['text'] for block in line]
      if [txt for txt in text if txt in ['ตั้งงบประมาณ', 'ผูกพันงบประมาณ', 'วงเงินทั้งสิ้น', 'ผลผลิต']]:
        continue
      scord = [block['sim_coord'] for block in line]
      for scrd, txt in zip(scord, text):
        if txt == 'บาท' and (scrd[0] > (self.whpage[0][1] - 200)).all():
          return scrd[0].tolist()

  @property
  def level_dict(self):
    lvldict = {}
    for line in self.Lines[1:]:
      fidx = line[0]
      pattern_lvel = get_patern_of_bullet(fidx['text'] + ' ')
      if pattern_lvel:
        if pattern_lvel[1] in lvldict.keys():
          lvldict[pattern_lvel[1]].append(fidx['sim_coord'][0][0])
        else:
          lvldict.update({pattern_lvel[1]: [fidx['sim_coord'][0][0]]})

    return {key: mode(lvldict[key]) for key in lvldict}

  def _simplify_coordinates(self, coord):
    scrd = np.sort(coord, axis=0)
    x = []
    y = []
    for c in scrd:
      x.append(c[0])
      y.append(c[1])
    return np.array([[(x[0] + x[1]) / 2, (x[2] + x[3]) / 2],
                     [(y[0] + y[1]) / 2, (y[2] + y[3]) / 2]])
  
  def _ypos_mean(self, list_of_blocks):
    if self._page == []:
      return None
    return np.mean([bx['sim_coord'][1] for bx in list_of_blocks], axis=0)

  def _lines(self, line_tolerance=None, yPos=False):
    line_tolerance = self.dline_tolerance if line_tolerance == None else line_tolerance
    if self._page == []:
      return None
    lines = []
    for b in self.get_blocks():
      if lines == []:
        lines.append([b])
      else:
        cm = b['sim_coord'][1]
        found = 0
        for line in lines:
          diff = abs(cm - self._ypos_mean(line))
          if diff[1] < line_tolerance:
            found = 1
            line.append(b)
            break
        if not found:
          lines.append([b])
    lines = [sorted(line, key = lambda i: i['sim_coord'][0][0]) for line in lines]
    if not yPos:
      return lines
    else:
      return [([block['text'] for block in line], self._ypos_mean(line).tolist()) for line in lines]

  def get_text_lines(self):
    if self._page == []:
      return []
    text_lines = []
    for line in self.get_text_list_lines():
      text_lines.append(' '.join(line))
    return text_lines

  def get_text_list_lines(self):
    if self._page == []:
      return []
    text_lines = []
    for line in self.Lines:
      text_lines.append([l['text'] for l in line])
    return text_lines    

  def xpos_text_lines(self):
    if self._page == []:
      return None
    xpos_lines = []
    text_lines = []
    for line in self.Lines:
      ax = np.array([bx['sim_coord'] for bx in line])
      xpos_lines.append(ax)
      text_lines.append([bx['text'] for bx in line])
    return  xpos_lines, text_lines

  def is_empty(self):
    if self._page == []:
      return True
    else:
      return False

  def __init__(self, index_page, page, pdfpage=None):
    self.dline_tolerance = 30
    self.index_page = index_page
    self.pdfpage = pdfpage
    self._hpage = page[:1]
    self._page = page[1:]
    if page:
      sim = self._simplify_coordinates([[coo['x'], coo['y']] for coo in page[0]['vertices']])
    else:
      sim = [np.NaN] * 2
    self.whpage = sim
    self.Lines = self._lines()

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

# %% [markdown]
# # FUNCTIONS

# %%
def get_range_in_page(page, ministry=[]):
  page_rage = []
  budgetary_u = []
  tempdict = {}
  newBU = 0
  newM = 0
  stw = [ministr[:int(len(ministr)*0.6)]for ministr in curr_doc.ministry]
  for line in page.Lines:
    width = page.whpage[0]
    m = (width[1] - width[0]) * 0.1
    bpt = get_patern_of_bullet(line[0]['text'])
    if bpt and bpt[1] == 1:
      newM = 0
      if line[0]['text'] == '7.':
        s = int(line[-1]['text'])
      elif line[0]['text'] == '8.':
        tempdict['budget_unit'] = ' '.join(budgetary_u)
        tempdict['ministry'] = ' '.join(ministry)
        tempdict['range'] = (s, int(line[-1]['text']))
        page_rage.append(tempdict)
        tempdict = {}
        budgetary_u = []
      newBU = 0
      continue
    if [sw for sw in stw if ' '.join([b['text'] for b in line]).startswith(sw)]:
      ministry = []
      newM = 1
    for b in line:
      if (b['sim_coord'][0] < width - m).any():
        if newBU and isthaichar(b['text']) == 0:
          budgetary_u += [b['text']]
        if newM and isthaichar(b['text']) == 0:
          ministry += [b['text']]
        if bpt and bpt[1] == 50:
          newBU = 1
          newM = 0
  return ministry, page_rage

def get_range():
  ministry = []
  page_rage = []
  for ipage in curr_doc.index_page:
    ministry, page_rage_ = get_range_in_page(curr_doc.page(ipage), ministry)
    page_rage += page_rage_
  page_rage

# %% [markdown]
# ### clean prefix

# %%
def clean_prefix(textlev, labellev):
  otext = []
  olabel = []
  for txt, lbel in zip(textlev, labellev):
    txtlbel = [{'text': text, 'label': label} for text, label in zip(txt, lbel)]
    if 'BULLET' in lbel:
      bltindex = lbel.index('BULLET')
      txt = txt[bltindex:]
      lbel = lbel[bltindex:]
    if 'FBAHT' in lbel :
      if 'ปี' in txt and 'FBAHT' in lbel:
        fyindex = txt.index('ปี')
        txt = txt[fyindex:]
        lbel = lbel[fyindex:]
    otext.append(txt)
    olabel.append(lbel)
  return otext, olabel

# %% [markdown]
# ### labelling

# %%
offer_x = 0

# %%
def labelling(coord, text, whpage):
    global offer_x
    labels = []
    xpos = []
    xbltpos = 0
    bltx = 0
    blt_s = ''

    fscy = [txt for txt in text if txt in ['ตั้งงบประมาณ', 'ผูกพันงบประมาณ', 'ตั้งงบประมา', 'งงบประมาณ', 'ตั้งบประมาณ']]

    jtxt = ''.join([txt for txt in text])
    
    if [txt for txt in SKIP_LINE if jtxt.startswith(txt)] or 'รายการผูกพัน' == jtxt:
        return None

    opmargin = 270 if curr_doc.ref_doc == '2022.3.15' else 220
    amout_margin = 270

    if not isinstance(offer_x, int):
      amout_margin = 280 if curr_doc.ref_doc != '2022.3.15' else whpage[0][1] - offer_x[0]

    for crd, txt in zip(coord, text):
        if txt in ['ขอจดสรร', 'ขอจัดสรร']:
          offer_x = crd[0]
          return None

        xpos += crd[0].tolist()
        if (crd[1] < whpage[1][0] + 25).all() and ''.join(text).isdigit():
            labels.append('PAGENUM')
        elif (np.array([len(txt) for txt in text]) < 5).all():
            return None
        elif get_patern_of_bullet(txt) and not labels and not fscy and not ',' in txt:
            labels.append('BULLET')
            xbltpos = crd[0].tolist()[0]
            bltx = [crd[0]]
            blt_s = txt
        elif bltx == 0 and (crd[1] < whpage[1][0] + opmargin).all() and (crd[0] < whpage[0][0] + 200).all() and txt == 'ผลผลิต':
            labels.append('OUTPUT')
            bltx = [crd[0]]
        elif bltx == 0 and (crd[1] < whpage[1][0] + opmargin).all() and (crd[0] < whpage[0][0] + 200).all() and txt == 'โครงการ':
            labels.append('PROJECT')
            bltx = [crd[0]]
        elif (crd[0] > whpage[0][1] - amout_margin).any() and not fscy and not txt.startswith('แผนงาน'):
            if re.match(r'[0-9]{1,3}(,[0-9]{1,3})*', txt) and txt.replace(',','').isdigit():
                labels.append('AMOUNT')
            else:
                labels.append('BAHT')
        elif fscy:
            if txt.isdigit():
                labels.append('FYEAR')
            elif re.match(r'[0-9]{1,3}(,[0-9]{1,3})*', txt):
                labels.append('FAMOUNT')
            else:
                labels.append('FBAHT')
        else:
            labels.append('NOTMATCH')
            if not re.match(r'(\(\d+\)|\d+\))$', blt_s) and len(labels) > 1 and labels[-2] in ['BULLET', 'PROJECT', 'OUTPUT'] and (txt in UNIT_NOUN or txt.startswith('และ')):
                labels[-2] = 'NOTMATCH'
                xbltpos = 0
                bltx = 0
                blt_s = ''
            if bltx and len(bltx) < 2:
                bltx.append(crd[0])

    return xbltpos if xbltpos else np.min(xpos), text, labels, bltx

# %%
re.match(r'(\(\d+\)|\d+\))$', '11+400')

# %%
def get_budget_plan(plist):
  npagelist, poslist, lineslist = [], [], []
  for ipge in plist:
    tmppos, tmptext = ipge.xpos_text_lines()
    poslist += tmppos
    lineslist += tmptext
    npagelist += [ipge.pdfpage] * len(tmptext)

  budget_plan = ''
  for coord, line in zip(poslist, lineslist):
    if [block for block in line if re.match('7\.[1-9]\.[1-9]', block)]:
      return budget_plan
    elif [block for block in line if block.startswith('แผนงาน')]:
      for bcrd, btext in zip(coord, line):
        if (bcrd[0] < 1200).all() and not re.match('7\.[1-9]', btext):
          budget_plan += btext
    elif budget_plan:
      budget_plan += ' '.join(line)

# %%
def xpos_text_lines(Lines):
  xpos_lines = []
  text_lines = []
  for line in Lines:
    ax = [bx['sim_coord'] for bx in line]
    xpos_lines.append(ax)
    text_lines.append([bx['text'] for bx in line])
  return  xpos_lines, text_lines

# %%
def clean_entry(plist, pl=False):
  pstart = curr_doc.start
  if pl:
    print([ipage.pdfpage for ipage in plist])
    print([ipage.index_page + 1 for ipage in plist])
  try:
    allxpos = [ipage.xSigPos[0] for ipage in plist] 
  except:
    print([ipage.pdfpage for ipage in plist])
  if len(plist) > 1:
    xdiffl = np.subtract(allxpos[0], allxpos)
  else:
    xdiffl = [0]
  
  if pl:
    print(xdiffl)

  npagelist, poslist, textlist, whplist = [], [], [], []

  for ipge, xdiff in zip(plist, xdiffl):
      tmppos, tmptext = xpos_text_lines(ipge.Lines)
      poslist += [np.add(tmpos, [[xdiff, xdiff], [0, 0]]) for tmpos in tmppos]
      textlist += tmptext
      npagelist += [ipge.pdfpage] * len(tmptext)
      whplist += [ipge.whpage] * len(tmptext)

  xposlev = []
  textlev = []
  labellev = []
  npagelev = []
  bltxlev = []

  for npage, coord, text, whp in zip(npagelist, poslist, textlist, whplist):
    if curr_doc.ref_doc == '2022.3.1' and npage in range(5, 8):
      if not get_patern_of_bullet(text[0]) or text[0] == '3.':
        continue
    olabel = labelling(coord, text, whp)

    if olabel == None:
      continue

    minxpos, textin, labels, bltx = olabel
    if 'PAGENUM' in labels:
      continue
    else:
      xposlev.append(minxpos)
      textlev.append(text)
      labellev.append(labels)
      npagelev.append(npage)
      bltxlev.append(bltx)

  textlev, labellev = clean_prefix(textlev, labellev)

  bltwdt = 0
  aftbltwdt = 0
  tbltx = 0
  oxposlev, otextlev, olabellev, onpagelev, obfbltxlev = [], [], [], [], []
  for idx, xpos, text, label, npage, bltx in zip(range(len(xposlev)), xposlev, textlev, labellev, npagelev, bltxlev):
    if isinstance(bltx, list):
      if len(bltx) < 2:
        print([p.pdfpage for p in plist])
        print(bltx, text, label, npage)
      bltwdt = bltx[0][0] - bltx[0][1]
      aftbltwdt = bltx[0][0] - bltx[1][0]
      tbltx = bltx
    if oxposlev:
      if text[0] == 'รวม':
        otextlev[-1] += text
        olabellev[-1] += label
      elif (('FBAHT' in label or 'FAMOUNT' in label or 'FYEAR' in label) or
          (('BAHT' in olabellev[-1] or 'FBAHT' in olabellev[-1]) and ('BULLET' in label or 'BAHT' in label)) or
          ('BULLET' in olabellev[-1] and 'BULLET' in label) or
          (len(labellev) > idx+1 and idx-1 >= 0 and 'BAHT' in labellev[idx-1] and 'BAHT' in labellev[idx+1] and 'BULLET' not in labellev[idx+1])):
        oxposlev.append(xpos)
        otextlev.append(text)
        olabellev.append(label)
        onpagelev.append(npage)
        obfbltxlev.append(tbltx)
      else:
        if ('BULLET' in olabellev[-1] and 'BULLET' in label):
          print('curr', xpos, text, label, npage)
        if isinstance(obfbltxlev[-1], int):
          print(' - ', xpos, text, label, npage)
        difblt = obfbltxlev[-1][0][0] - xpos
        difblt_tolerance = 12 if curr_doc.ref_doc != '2022.3.5' else 17
        if (difblt < difblt_tolerance and not ('BULLET' in olabellev[-1] and 'BULLET' in label)  and (bltwdt - 15 < difblt or aftbltwdt - 20 < difblt or
                            (('OUTPUT' in olabellev[-1] and -113 < difblt) or 
                             ('PROJECT' in olabellev[-1] and -130 < difblt))) or
            len(labellev) > idx+1 and idx-1 >= 0 and 'BAHT' not in labellev[idx-1] and 
            ('BAHT' in labellev[idx+1] or 'FBAHT' in labellev[idx+1] or 'FYEAR' in labellev[idx+1])):
          otextlev[-1] += text
          olabellev[-1] += label
        else:
          print('‣ prev', oxposlev[-1], otextlev[-1], olabellev[-1], onpagelev[-1])
          print('‣ curr', xpos, text, label, npage)
          print(obfbltxlev[-1])
          print(bltwdt - 15, difblt, bltwdt - 15 < difblt, aftbltwdt - 20)
    else:
      oxposlev.append(xpos)
      otextlev.append(text)
      olabellev.append(label)
      onpagelev.append(npage)
      obfbltxlev.append(tbltx)
  if pl:
    for npge, x_, text, labl in zip(onpagelev, oxposlev, otextlev, olabellev):
      print(npge, x_, [(tx, lb) for tx, lb in zip(text, labl)])

  return oxposlev, otextlev, olabellev, onpagelev

# %% [markdown]
# ### get entry

# %%
garbage = [chr(x) for x in range(3585, 3654)] + ['|', ':', 'ส่', 'de', 'ายอิน']

# %%
 def get_entry(cleaned_entry, fp=False):
  xposlev, textlev, labellev, npagelev = cleaned_entry

  for text, label, idx in zip(textlev, labellev, range(len(textlev))):
    if 'BULLET' not in label and 'FBAHT' not in label and 'OUTPUT' not in label and 'PROJECT' not in label:
      tj = ''.join(textlev[idx])
      if '(ชดเชยงบ' in tj or '(ชุดเชยงบประมาณ' in tj or tj.startswith('กิจกรรม') or tj.startswith('กิจรรม'):
        xposlev[idx] = None
        textlev[idx] = None
        labellev[idx] = None
        npagelev[idx] = None
      elif get_patern_of_bullet(text[0]):
        label[0] = 'BULLET'
      else:
        print('🚨 [1] is not \'BULLET\': ', text)

  xposlev = [x for x in xposlev if x != None]
  textlev = [x for x in textlev if x != None]
  labellev = [x for x in labellev if x != None]
  npagelev = [x for x in npagelev if x != None]

  iserrorlev = [False] * len(xposlev)
  loglev = [''] * len(xposlev)

  # get level dict
  lev = []
  level_tolerance = 11 
  for i in range(len(xposlev)):
    if lev == []:
      lev.append({'xPos': [xposlev[i]], 'index': [i]})
    else:
      diff = abs(np.subtract([np.mean(lv['xPos']) for lv in lev], xposlev[i]))
      if np.amin(diff) > level_tolerance:
        lev.append({'xPos': [xposlev[i]], 'index': [i]})
      else:
        idx = np.where(diff == np.amin(diff))[0][0]
        lev[idx]['xPos'].append(xposlev[i])
        lev[idx]['index'].append(i)

  # get level list of int
  level_dict = lev
  srtd_idx = sorted([(lv['index'], np.mean(lv['xPos'])) for lv in level_dict],
          key=lambda tup: tup[1])
  srtd_idx = [idx[0] for idx in srtd_idx]
  levs = []
  t_levs = len(srtd_idx)
  for idx in range(len(xposlev)):
    mask = np.array([idx in tst for tst in srtd_idx])
    n = np.arange(t_levs)[mask]
    levs.append(n[0])
 
  entry = []
  prjopt = {'Project': '', 'Output': ''}

  crdstack = []
  bltstack = []
  for pnum, xpos, level, text, label, idx in zip(npagelev, xposlev, levs, textlev, labellev, range(len(loglev))):
    if 'รายการบุคลากรภาครัฐ' in text or 'รายการบุคลากรภาครััฐ' in text:
      iserrorlev[idx], loglev[idx] = True, 'LINE SKIPED'
      continue

    if 'วงเงินทั้งสิ้น' in text:
      continue
    if 'วงเงินทั้งสิน' in text:
      continue

    if '(1) รายการไม่ผูกพัน' in ' '.join(text):
      continue

    context = []
    for lbel, txt in zip(label, text):
      if lbel == 'NOTMATCH' and txt not in garbage:
        context.append(txt)
    context = ' '.join(context)

    if 'OUTPUT' in label or 'PROJECT' in label:
      if 'OUTPUT' in label:
        prjopt['Output'] = context
      else:
        prjopt['Project'] = context
      continue
    
    elif 'FAMOUNT' in label or 'FBAHT' in label:
      amount = text[label.index('FAMOUNT')] if 'FAMOUNT' in label else '0'
      if re.match('\d{1,3}(,\d{3})*(\.\d+)?$', amount):
        amount = float(''.join([x for x in amount if x != ',']))
      else:
        temp['DEBUG_LOG'].append('AMOUNT FORMAT IS WORONG')
        print(amount, pnum, level, text, label)

      if entry:
        entry[-1]['is_obliged'] = 1
        if label.count('FYEAR') == 2:
          year = [txt for lbel, txt in zip(label, text) if lbel == 'FYEAR']
          nyr = int(year[1]) - int(year[0]) + 1
          fiscal_year = {i : '{:,}'.format(amount / nyr) for i in range(to_gregorian(year[0]), to_gregorian(year[1])+1)}
        elif label.count('FYEAR') == 1:
          if isinstance(amount, float):
            amount = f'{amount:,}'
          fiscal_year = {to_gregorian(text[label.index('FYEAR')]): amount}
        else:
          print('🚨 no \'FYEAR\'', pnum, level, text, label)
          iserrorlev[idx], loglev[idx] = True, '\'FYEAR\' NOT FOUND'
          continue

        if isinstance(entry[-1]['fiscal_year'], int):
          entry[-1]['fiscal_year'] = fiscal_year
        elif isinstance(entry[-1]['fiscal_year'], dict):
          entry[-1]['fiscal_year'].update(fiscal_year)
        else:
          print('🚨 type not match', entry[-1]['fiscal_year'])
          iserrorlev[idx], loglev[idx] = True, 'TYPE NOT MATCH'
      else:
        print('🚨 entry is empty', pnum, level, text, label)
        iserrorlev[idx], loglev[idx] = True, 'ENTRY IS EMPTY'
        
      continue

    context = ' '.join([txt for lbel, txt in zip(label, text) if lbel == 'NOTMATCH'])
    if curr_doc.ref_doc == '2022.3.15':
      if len([x for x in label if x == 'AMOUNT']) != 2:
        print('ONLY ONE AMOUNT ON PAGE {} {}'.format(pnum, text), label)
      amount = text[label.index('AMOUNT')] if 'AMOUNT' in label else '0'

      if re.match('\d{1,3}(,\d{3})*(\.\d+)?$', amount):
        amount = float(''.join([x for x in amount if x != ',']))
      else:
        print(amount,': ', pnum, level, text, label)
      if isinstance(amount, float):
          amount = f'{amount:,}'
        
    else:
      amount = text[label.index('AMOUNT')] if 'AMOUNT' in label else '0'
    if not 'AMOUNT' in label:
        if 'BAHT' in label and re.match(r'[0-9]{1,3}(,[0-9]{1,3})*', text[label.index('BAHT') - 1]):
            amount = text[label.index('BAHT') - 1]
        else:
            print('No amount found', pnum, level, text, label)
    
    temp = {'context': context,
            'ref_line': text,
            'amount': amount,
            'coord_level': level,
            'page': pnum,
            'fiscal_year': int(curr_doc.fiscal_year),
            'is_obliged': 0,
            'DEBUG_LOG': []}

    blt = 0
    bltlevel = -1
    clevel = level
    bltfound = 0
    if 'BULLET' in label:
      bltfound = 1
      blt = text[label.index('BULLET')]
      bltlevel = get_patern_of_bullet(text[label.index('BULLET')])[1]
      temp['bullet_level'] = (bltlevel, blt)
    else:
      temp['DEBUG_LOG'].append('NO BULLET FOUND')
      iserrorlev[idx], loglev[idx] = True, 'NO BULLET FOUND'

    db = crdstack[:]
    if crdstack:
      if crdstack[-1] < clevel:
        crdstack.append(clevel)
      elif crdstack[-1] > clevel:
        if not clevel in crdstack:
          crdstack[-1] = clevel
        while crdstack[-1] != clevel:
          crdstack.pop()
    else:
      crdstack.append(clevel)
    temp['crdstack_level'] = len(crdstack)

    if bltlevel != -1:
      db = bltstack[:]
      if bltstack:
        if bltstack[-1] < bltlevel:
          bltstack.append(bltlevel)
        elif bltstack[-1] > bltlevel:
          if not bltlevel in bltstack:
            bltstack[-1] = bltlevel
          while bltstack[-1] != bltlevel:
            bltstack.pop()
      else:
        bltstack.append(bltlevel)
      temp['bltstack_level'] = len(bltstack)
    else:
      temp['bltstack_level'] = len(bltstack)
      print('🚨 bulltet_lebel is -1: ', text, label)

    if temp['bltstack_level'] != temp['crdstack_level']:
      if bltfound:
        temp['level'] = temp['bltstack_level']
      else:
        temp['level'] = temp['crdstack_level']

      iserrorlev[idx], loglev[idx] = True, 'LEVEL NOT MATCH'
      log = 'LEVEL NOT MATCH level: by x position {}, by pattern {}'.format(temp['crdstack_level'], temp['bltstack_level'])
      temp['DEBUG_LOG'].append(log)
    else:
      temp['level'] = temp['bltstack_level']

    if temp['level'] == 1 and temp['context'] not in ['งบบุคลากร', 'งบดำเนินงาน', 'งบลงทุน', 'งบเงินอุดหนุน', 'งบรายจ่ายอื่น']:
      temp['DEBUG_LOG'].append('CATEGORY_LV1 is not as descripted')

    if temp['DEBUG_LOG']:
      print(temp['DEBUG_LOG'])
      print('page: {}, [\'level\']: {}, xPos: {}, text: {}'.format(pnum, temp['level'], xpos, temp['ref_line']))
    entry.append(temp)
  
  semi_raw = []
  for pnum, xpos, level, text, label, iserror, log in zip(npagelev, xposlev, levs, textlev, labellev, iserrorlev, loglev):
    semi_raw.append({'text': text,
          'minxpos': xpos,
          'label': label,
          'page_number': pnum,
          'error_found': iserror,
          'log': log})

  return prjopt, entry, semi_raw

# %%
def get_categorys_lv(list_of_dict):
  CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4, CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION = [''] * 7
  DEBUG_LOG = []
  for ite in list_of_dict:
    if ite['DEBUG_LOG']:
      DEBUG_LOG += ite['DEBUG_LOG']
    if ite['level'] == 1:
      CATEGORY_LV1 = ite['context']
    elif ite['level'] == 2:
      CATEGORY_LV2 = ite['context']
    elif ite['level'] == 3:
      CATEGORY_LV3 = ite['context']
    elif ite['level'] == 4:
      CATEGORY_LV4 = ite['context']
    elif ite['level'] == 5:
      CATEGORY_LV5 = ite['context']
    elif ite['level'] == 6:
      CATEGORY_LV6 = ite['context']
    elif ite['level'] == 7:
      ITEM_DESCRIPTION = ite['context']
    else:
      print('LEVEL MORE THAN 7')

  if not ITEM_DESCRIPTION:
    if CATEGORY_LV6:
      ITEM_DESCRIPTION = CATEGORY_LV6
      CATEGORY_LV6 = ''
    elif CATEGORY_LV5:
      ITEM_DESCRIPTION = CATEGORY_LV5
      CATEGORY_LV5 = ''
    elif CATEGORY_LV4:
      ITEM_DESCRIPTION = CATEGORY_LV4
      CATEGORY_LV4 = ''
    elif CATEGORY_LV3:
      ITEM_DESCRIPTION = CATEGORY_LV3
      CATEGORY_LV3 = ''
    elif CATEGORY_LV2:
      ITEM_DESCRIPTION = CATEGORY_LV2
      CATEGORY_LV2 = ''
    elif CATEGORY_LV1:
      ITEM_DESCRIPTION = CATEGORY_LV1
      CATEGORY_LV1 = ''
  DEBUG_LOG = list(set(DEBUG_LOG))
  DEBUG_LOG = ' - '.join(DEBUG_LOG)
  return CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4, CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION, DEBUG_LOG

# %%
def get_rows_of_budg_unit(running_id, budget_plan_details, bud_u):

  REF_DOC = curr_doc.ref_doc
  ITEM_ID = '{}.{}'.format(REF_DOC, running_id)
  REF_PAGE_NO = -1
  DEBUG_LOG = ''
  MINISTRY = budget_plan_details['ministry']
  BUDGETARY_UNIT = budget_plan_details['budget_unit']
  CROSS_FUNC = budget_plan_details['is_cross_func']
  BUDGET_PLAN = budget_plan_details['budget_plan']
  OUTPUT = budget_plan_details['Output']
  PROJECT = budget_plan_details['Project']

  CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4, CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION = [''] * 7
  FISCAL_YEAR = curr_doc.fiscal_year
  AMOUNT = -1
  OBLIGED = 0

  stack = []
  rows = []
  for item in bud_u:
    if stack:
      if stack[-1]['level'] < item['level']:
        stack.append(item)
      elif stack[-1]['level'] > item['level']:
        rows.append([x for x in stack])
        stack.pop()
      elif stack[-1]['level'] == item['level']:
        rows.append([x for x in stack])
      if stack:
        stack.pop()
      stack.append(item)
    else:
      stack.append(item)
      
  rows.append([x for x in stack])

  rows_of_lists = []

  for row in rows[:]:
    if not row:
      continue
    itms = row[-1]
    REF_PAGE_NO = itms['page']
    OBLIGED = itms['is_obliged']
    CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4, CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION, DEBUG_LOG = get_categorys_lv([x for x in row])
    
    # special case
    if MINISTRY == 'งบกลาง':
      BUDGET_PLAN = CATEGORY_LV2
      CROSS_FUNC = BUDGET_PLAN.startswith('แผนงานบูรณาการ')
      CATEGORY_LV1 = ''
      CATEGORY_LV2 = ''
      CATEGORY_LV3 = ''

    if itms['is_obliged']:
      for fy, amt in itms['fiscal_year'].items():
        FISCAL_YEAR = fy
        AMOUNT = amt
        ITEM_ID = '{}.{}'.format(REF_DOC, running_id)
        running_id += 1
        rows_of_lists.append([ITEM_ID, REF_DOC, REF_PAGE_NO, MINISTRY, BUDGETARY_UNIT, np.bool_(CROSS_FUNC), BUDGET_PLAN, OUTPUT,
                              PROJECT, CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4,
                              CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION,
                              FISCAL_YEAR, AMOUNT, np.bool_(OBLIGED), DEBUG_LOG])
    else:
      FISCAL_YEAR = itms['fiscal_year']
      AMOUNT = itms['amount']
      ITEM_ID = '{}.{}'.format(REF_DOC, running_id)
      running_id += 1
      rows_of_lists.append([ITEM_ID, REF_DOC, REF_PAGE_NO, MINISTRY, BUDGETARY_UNIT, np.bool_(CROSS_FUNC), BUDGET_PLAN, OUTPUT,
                            PROJECT, CATEGORY_LV1, CATEGORY_LV2, CATEGORY_LV3, CATEGORY_LV4,
                            CATEGORY_LV5, CATEGORY_LV6, ITEM_DESCRIPTION, FISCAL_YEAR, AMOUNT, np.bool_(OBLIGED), DEBUG_LOG])
  return running_id, rows_of_lists

# %% [markdown]
# ### get data frame

# %%
def get_data_frame(doc, to_csv=False):
  lemtestrange = doc.range
#   for i, lrange in enumerate(lemtestrange[:]):
#       print(i, lrange['budget_unit'], lrange['range'])

  pstart = doc.start
  listpage = []
  for lrange in lemtestrange:
      startp, endp = lrange['range']
      for ipage in range(startp, endp):
          listpage.append(doc.page(ipage + pstart))
          listpage[-1].pdfpage = ipage

  idtpages = []
  ihdpages = []
  tmphdict = {}
  semi_raw_entry = {doc.ref_doc :[]}
  Header = []
  Detail = []

  bgplan = ''
  lemrange = lemtestrange[:]
  df = pd.DataFrame(columns=cols)
  running_id = 0

  if curr_doc.ref_doc == '2022.3.1':
    tmppages = []
    idx = 0
    while (listpage[0].pdfpage < 8):
      tmppages.append(listpage.pop(0))
      idx += 1
    prjopt, entry, semi_raw = get_entry(clean_entry(tmppages))
    tmph = {'ministry': 'งบกลาง',
            'budget_unit': 'งบกลาง', 
            'is_cross_func': 0, 
            'budget_plan':'', 
            'Output': '', 
            'Project': '',
            'ref_page': []}
    Detail.append(entry)
    Header.append(tmph)

  for ipage in tqdm(listpage, desc=doc.ref_doc):
      text = '\n'.join(ipage.get_text_lines())
      headerw = ['หน่วย : ล้านบาท', 'หน่วยเล้านบาท', 'วัตถุประสงค์', 'หน่วย:ล้านบาท', 'หน่วยนับ', 'หน่วยล้านบาท']
      if not [hw for hw in headerw if hw in text]:
          # detail
          if ihdpages:
            tbgplan = get_budget_plan(ihdpages)
            bgplan = tbgplan if tbgplan else bgplan
            budget_unit = ''
            ministry = ''
            while not budget_unit:
              if lemrange[0]['range'][0] <= ihdpages[0].pdfpage < lemrange[0]['range'][1]:
                ministry = lemrange[0]['ministry']
                budget_unit = lemrange[0]['budget_unit']
              else:
                lemrange.pop(0)
            tmphdict = {'ministry': ministry, 'budget_unit': budget_unit,
                        'budget_plan': bgplan, 'ref_page': [i.pdfpage for i in ihdpages],
                        'is_cross_func': bgplan.startswith('แผนงานบูรณาการ')}
            ihdpages = []
          idtpages.append(ipage)
      else:
          # header
          if idtpages:
            prjopt, entry, semi_raw = get_entry(clean_entry(idtpages))
            semi_raw_entry[doc.ref_doc].append(semi_raw)
            Detail.append(entry)
            tmphdict.update(prjopt)
            Header.append(tmphdict)
            idtpages = []
          ihdpages.append(ipage)

  if idtpages:
    prjopt, entry, semi_raw = get_entry(clean_entry(idtpages))
    semi_raw_entry[doc.ref_doc].append(semi_raw)
    Detail.append(entry)
    tmphdict.update(prjopt)
    Header.append(tmphdict)
    
  for header, detail in zip(Header, Detail):
    running_id, rows = get_rows_of_budg_unit(running_id, header, detail)
    new_row = pd.DataFrame(rows, columns=cols)
    df = df.append(new_row, ignore_index=True)

  # print('entries contain error'.upper())
  # tempe = []
  # for buplan, header in zip(semi_raw_entry[curr_doc.ref_doc], Header):
  #   tempd = {}
  #   tempa = []
  #   curr_page = 0
  #   for entry in buplan:
  #     if entry['error_found']:
  #       print(entry)
  #     if curr_page and curr_page == entry['page_number']:
  #       tempa.append({
  #           'minxpos': entry['minxpos'],
  #           'error_found': entry['error_found'],
  #           'log': entry['log'],
  #           'block': [{'text': txt, 'label': lbel} for txt, lbel in zip(entry['text'], entry['label'])]
  #           })
  #     elif curr_page != entry['page_number']:
  #       if curr_page != 0:
  #         tempd.update({curr_page: tempa})
  #         tempa = []
  #       curr_page = entry['page_number']
  #   tempd.update({curr_page: tempa})
  #   header.update({'page': tempd})
  #   tempe.append(header)

  # semirawentry = {curr_doc.ref_doc: tempe}
  if to_csv:
    # with open("/content/drive/MyDrive/data/26-Jul/{}-raw-entry.json".format(curr_doc.ref_doc.replace('.', '-')), "w", encoding="utf8") as file:
    #     json.dump(semirawentry, file, ensure_ascii=False, cls=NpEncoder)

    df.to_csv('/content/drive/MyDrive/data/26-Jul/{}.csv'.format(curr_doc.ref_doc.replace('.', '-')))
  return df

# %% [markdown]
# ### globe var

# %%
cols = ['ITEM_ID','REF_DOC','REF_PAGE_NO','MINISTRY','BUDGETARY_UNIT',
        'CROSS_FUNC?','BUDGET_PLAN','OUTPUT','PROJECT','CATEGORY_LV1',
        'CATEGORY_LV2','CATEGORY_LV3','CATEGORY_LV4','CATEGORY_LV5',
        'CATEGORY_LV6', 'ITEM_DESCRIPTION','FISCAL_YEAR','AMOUNT','OBLIGED?', 'DEBUG_LOG']

# %%
UNIT_NOUN = ['ไร่', 'กิโลเมตร', 'กม.','มิลลิกรัม','ชีซี', 'ซีซี', 'แห่ง', 'ระบบ', 'กิจกรรม', 'โครงการ','ฟุต','กิโลวัตต์', 'รายการ', 'ช่องสัญญาณ',
             'เตียง', 'องศา', 'ต้นแบบ', 'เครื่อง', 'ชุด', 'คัน', 'ลิตร','ล้อ', 'เมตร', 'จังหวัดริมน้ำโขง', 'งาน', 'ไมครอน',
             'คัน/ลำ/เครื่อง', 'แรงม้า', 'ชั้น', 'พรรษา', 'ตารางเมตร', 'ลูกบาศก์เมตร/วัน', 'ถุง', 'สายทาง', 'kW',
             'อาคาร', 'หลัง', 'ห้อง', 'สถานการณ์', 'กิโลกรัม', 'เกลียวผสม', 'ฉบับ','ล้านบาท', 'ไมโครกรัม']

# %%
SKIP_LINE = ['วงเงินทั้งิ้น', 'เงินนอกงบประมาณ', 'เงินงบประมาณ', 'รายการบุคลากรภาครัฐ', 'รายการบุคลากรภาครั้ัฐ',
             'วงเงินทั้งสิ้น', 'วงเงินทั้งสิ้น','วงเงินทั่งสิ้น', 'วงเงินทั้งส้น', 'วงเงินทิ้งส้น','วงเงินทั่้งสิ้น', 'วงเงินทั้งสิ้',
             'วงเงินทิ่้งสิ้น','วงเงินทิ้งสิ้น', 'วงเงินทิ่งสิ้น','วงเงินทั้งสิน', 'งงบประมาณ', 'วงเงินทิ้งสิน', 'วงเงินท้งสิ้น',
             'วงเงินทิ่งสิน', 'วงเงินทั้งิน', 'วงเงินทุ่งสิน',
             
             'รายการผูกพัน', 'รายการไม่ผูกพัน', 'ประกอบด้วย', # 3.15
             
             'รายละเอียดงบประมาณจำแนกตามงบรายจ่าย', 'งบประมาณทั้งสิ้น', 'วงเงินทั้งสน', 'วงเงินทั้งี']

# %% [markdown]
# # implementation

# %%
# %%time
tbg = ThaiBudget('/content/drive/MyDrive/data/thaiBudget2022.json')
# Out:
# CPU times: user 8.86 s, sys: 2.54 s, total: 11.4 s
# Wall time: 16.7 s

# %%
for rd in tbg.docs[:]:
  curr_doc = tbg.get_doc(rd)
  df = get_data_frame(curr_doc, True)
# Out:
# ['CATEGORY_LV1 is not as descripted']
# page: 5, ['level']: 1, xPos: 240.0, text: ['1.', 'แผนงานพื้นฐาน', '400,747,326,800', 'บาท']
# ['CATEGORY_LV1 is not as descripted']
# page: 6, ['level']: 1, xPos: 246.0, text: ['2.', 'แผนงานยุทธศาสตร์', '170,300,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 6, ['level']: 2, xPos: 247.0, text: ['2.1', 'แผนงานยุทธศาสตร์พัฒนาระบบการเตรียมพร้อมแห่งชาติและระบบบริหารจัดการภัยพิบัติ', '6', 'ญ', '5,000,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 6, ['level']: 3, xPos: 282.0, text: ['2.1.1', 'ค่าใช้จ่ายชดใช้เงินทดรองราชการเพื่อช่วยเหลือผู้ประสบภัยพิบัติกรณีฉุกเฉิน', '5,000,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 6, ['level']: 2, xPos: 246.0, text: ['2.2', 'แผนงานยุทธศาสตร์เสริมสร้างพลังทางสังคม', '2,300,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 6, ['level']: 3, xPos: 282.0, text: ['2.2.1', 'ค่าใช้จ่ายตามโครงการอันเนื่องมาจากพระราชดำริ', '2,300,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 7, ['level']: 2, xPos: 247.0, text: ['2.3', 'แผนงานยุทธศาสตร์สร้างหลักประกันทางสังคม', '74,000,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 7, ['level']: 3, xPos: 283.0, text: ['2.3.1', 'ค่าใช้จ่ายในการรักษาพยาบาลข้าราชการ', 'ลูกจ้าง', 'และพนักงานของรัฐ', '74,000,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 7, ['level']: 2, xPos: 247.0, text: ['2.4', 'แผนงานบริหารเพื่อรองรับกรณีฉุกเฉินหรือจำเป็น', '89,000,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 7, ['level']: 3, xPos: 283.0, text: ['2.4.1', 'เงินสำรองจ่ายเพื่อกรณีฉุกเฉินหรือจำเป็น', '89,000,000,000', 'บาท']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.1', max=588.0, style=ProgressStyle(description_wid…
# No amount found 37 4 ['(1)', 'ค่าก่อสร้างอาคารพิพิธภัณฑ์', 'ระยะที่', '1', 'เขตวังทองหลาง', 'กรุงเทพมหานคร', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT']
# No amount found 37 4 ['(3)', 'ค่าควบคุมงานก่อสร้างอาคารพิพิธภัณฑ์', 'ระยะที่', '1', 'เขตวังทองหลาง', 'กรุงเทพมหานคร', 'บ', 'น', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 450 4 ['(5.1)', 'ค่าก่อสร้างศูนย์การเรียนรู้และวิจัยเฉลิมพระเกียรติ', '60', 'พรรษา', 'เจ้าฟ้าจุฬาภรณ์', 'แขวงตลาดบางเขน', 'เขตหลักสี่', 'กรุงเทพมหานคร', '1', 'งาน', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 682, ['level']: 2, xPos: 225.0, text: ['1)', 'ค่าใช้จ่ายในการฝึก', 'ศึกษา', 'ทางการทหาร', '12,651,700', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 682, ['level']: 2, xPos: 228.0, text: ['2)', 'ค่าใช้จ่ายในการดำเนินงานเทคโนโลยีสารสนเทศและการสื่อสาร', '58,383,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 682, ['level']: 2, xPos: 228.0, text: ['3)', 'งานปรับปรุงรถปฏิบัติการรับสัญญาณภาพถ่ายดาวเทียมแบบเคลื่อนที่', '6,300,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 682, ['level']: 2, xPos: 223.0, text: ['4)', 'การสรรพกำลังกลาโหม', '2,924,700', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 686, ['level']: 2, xPos: 226.0, text: ['1)', 'ค่าใช้จ่ายในการปรับปรุงหน่วย', '107,893,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 722, ['level']: 2, xPos: 138.0, text: ['(1)', 'ค่าใช้จ่ายในการดำรงสภาพกำลังกองทัพ', '6,272,229,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 722, ['level']: 3, xPos: 178.0, text: ['(1.1)', 'ค่าใช้จ่ายในการฝึกอบรมและศึกษาต่างประเทศ', '32,195,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 722, ['level']: 3, xPos: 178.0, text: ['(1.2)', 'ค่าใช้จ่ายในการฝึก', 'ศึกษาทางการทหาร', '2,038,571,600', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 722, ['level']: 3, xPos: 178.0, text: ['(1.3)', 'ค่าใช้จ่ายในการสนับสนุนการส่งกำลังและซ่อมบำรุง', 'และผลิตเพื่อแจกจ่าย', '3,240,902,300', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 722, ['level']: 3, xPos: 177.5, text: ['(1.4)', 'ค่าใช้จ่ายใ', 'ายในการจัดหาสิ่งอุปกรณ์', 'และชิ้นส่วนซ่อมคงคลัง', '876,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 722, ['level']: 3, xPos: 178.0, text: ['(1.5)', 'ค่าใช้จ่ายในการเตรียมกำลังพลสำรองเพื่อป้องกันประเทศ', '83,959,700', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 722, ['level']: 3, xPos: 200.0, text: ['(22.1)', 'โครงการจัดหายุทโธปกรณ์', '3,146,863,700', 'บาท']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.2', max=343.0, style=ProgressStyle(description_wid…
# ['CATEGORY_LV1 is not as descripted']
# page: 102, ['level']: 1, xPos: 162.5, text: ['3.', 'งบรายจ่ายอื่น', 'ว่ายอิน', '25,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 5']
# page: 310, ['level']: 5, xPos: 235.0, text: ['(1)', 'ค่าก่อสร้างสนามกีฬาและสิ่งก่อสร้างประกอบที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '15,200,000', 'บาท', 'รวม', '2', 'รายการ', '(รวม', '2', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 327, ['level']: 4, xPos: 426.0, text: ['(1.19)', 'ค่าสาธารณูปโภค', '5,685,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 327, ['level']: 4, xPos: 422.0, text: ['(1.20)', 'ค่าใช้จ่ายดำเนินงาน', '(บริหารต่อเนื่อง)', '17,801,300', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 4']
# page: 335, ['level']: 4, xPos: 261.0, text: ['(1)', 'ค่าปรับปรุงหอศิลปวัฒนธรรมพื้นเมืองน่านและแหล่งเรียนรู้ศิลปวัฒนธรรมล้านนา', '40,651,700', 'บาท', 'ตะวันออก', 'พื้นที่ใช้สอย', '3,100', 'ตร.ม.', 'และสิ่งก่อสร้างประกอบพร้อมปรับปรุงภูมิทัศน์', 'อำเภอเมืองน่าน', 'จังหวัดน่าน', '1', 'แห่ง']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 3']
# page: 335, ['level']: 3, xPos: 261.0, text: ['2)', 'ค่าใช้จ่ายเพื่อสร้างรายได้จากการท่องเที่ยวโดยชุมชนเชิงสร้างสรรค์ผ่านตลาดมูลค่าสูง', '15,369,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 3']
# page: 335, ['level']: 3, xPos: 261.0, text: ['3)', 'ค่าใช้จ่ายในการพัฒนาปรับปรุงองค์ประกอบของเมืองสร้างสรรค์ในพื้นที่พิเศษ', '26,824,300', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 3']
# page: 335, ['level']: 3, xPos: 261.0, text: ['4)', 'ค่าใช้จ่ายในการพัฒนาเมืองและชุมชนที่มีศักยภาพด้านการท่องเที่ยวเชิงสร้างสรรค์และ', 'ๆ', 'น', 'วัฒนธรรม', '18,259,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 5']
# page: 421, ['level']: 5, xPos: 226.0, text: ['(1)', 'ค่าก่อสร้างอาคารที่ทำการและสิ่งก่อสร้างประกอบที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '57,100', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 1']
# page: 440, ['level']: 1, xPos: 232.5, text: ['2.', 'งบลงทุน', '9,246,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 440, ['level']: 2, xPos: 250.0, text: ['2.1', 'ค่าครุภัณฑ์', 'ที่ดินและสิ่งก่อสร้าง', '9,246,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 440, ['level']: 3, xPos: 267.0, text: ['2.1.1', 'ค่าครุภัณฑ์', '8,160,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 440, ['level']: 4, xPos: 284.0, text: ['2.1.1.1', 'ครุภัณฑ์ยานพาหนะและขนส่ง', '5,160,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(1)', 'รถบรรทุก', '(ดีเซล)', 'ขนาด', '3', 'ตัน', '6', 'ล้อ', 'ปริมาตรกระบอกสูบไม่ต่ำกว่า', '3,000', 'ซีซี', 'หรือกำลังเครื่องยนต์สูงสุดไม่ตำกว่า', '80', 'กิโลวัตต์', 'ศูนย์เรียนรู้การพัฒนาสตรีและครอบครัวภาคกลาง', 'จังหวัดนนทบุรี', 'ตำบลบางตลาด', 'อำเภอปากเกร็ด', 'จังหวัดนนทบุรี', '1', 'คัน', '1,075,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(2)', 'รถบรรทุก', '(ดีเซล)', 'ขนาด', '1', 'ตัน', 'ปริมาตรกระบอกสูบไม่ต่ำกว่า', '2,400', 'ซีซี', 'หรือกำลังเครื่องยนต์สูงสุดไม่ต่ำกว่า', '110', 'กิโลวัตต์', 'ขับเคลื่อน', '4', 'ล้อ', 'แบบดับเบิ้ลแค็บ', 'ศูนย์เรียนรู้การพัฒนาสตรี', 'และครอบครัวภาคใต้', 'จังหวัดสงขลา', 'ตำบลกำแพงเพชร', 'อำเภอรัตภูมิ', 'จังหวัดสงขลา', '1', 'คัน', '1,092,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(3)', 'รถประจำตำแหน่ง', 'ระดับอธิบดี', 'ปริมาตรกระบอกสูบไม่เกิน', '2,500', 'ซีซี', 'หรือกำลังเครื่องยนต์สูงสุดไม่เกิน', '160', 'กิโลวัตต์', 'หรือกำลังมอเตอร์ไฟฟ้าสูงสุด', 'ไม่เกิน', '150', 'กิโลวัตต์', 'กรมกิจการสตรีและสถาบันครอบครัว', 'แขวงคลองมหานาค', 'เขตป้อมปราบศัตรูพ่าย', 'กรุงเทพมหานคร', '1', 'คัน', '1,676,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(4)', 'รถประจำตำแหน่ง', 'ระดับรองอธิบดี', 'ปริมาตรกระบอกสูบไม่เกิน', '2,200', 'ซีซี', 'หรือกำลังเครื่องยนต์สูงสุดไม่เกิน', '130', 'กิโลวัตต์', 'หรือกำลังมอเตอร์ไฟฟ้าสูงสุดไม่เกิน', '150', 'กิโลวัตต์', 'กรมกิจการสตรีและสถาบันครอบครัว', 'แขวงคลองมหานาค', 'เขตป้อมปราบศัตรูพ่าย', 'กรุงเทพมหานคร', '1', 'คัน', '1,317,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 440, ['level']: 4, xPos: 284.0, text: ['2.1.1.2', 'ครุภัณฑ์คอมพิวเตอร์', '3,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(1)', 'ระบบเครือข่ายไร้สายของกรมกิจการสตรีและสถาบันครอบครัว', 'แขวงคลองมหานาค', 'เขตป้อมปราบศัตรูพ่าย', 'กรุงเทพมหานคร', '1', 'ระบบ', '3,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 440, ['level']: 3, xPos: 267.0, text: ['2.1.2', 'ค่าที่ดินและสิ่งก่อสร้าง', '1,086,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 440, ['level']: 4, xPos: 284.0, text: ['2.1.2.1', 'ค่าปรับปรุงอาคารที่ทำการและสิ่งก่อสร้างประกอบ', '876,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(1)', 'ค่าปรับปรุงอาคารที่ทำการและสิ่งก่อสร้างประกอบที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '876,000', 'บาท', 'รวม', '2', 'รายการ', '(รวม', '2', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 440, ['level']: 4, xPos: 284.0, text: ['2.1.2.2', 'ค่าปรับปรุงอาคารที่พักอาศัยและสิ่งก่อสร้างประกอบ', '210,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 440, ['level']: 5, xPos: 302.0, text: ['(1)', 'ค่าปรับปรุงอาคารที่พักอาศัยและสิ่งก่อสร้างประกอบที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '210,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.3(1)', max=512.0, style=ProgressStyle(description_…
# ['CATEGORY_LV1 is not as descripted']
# page: 241, ['level']: 1, xPos: 202.5, text: ['2.', 'งบรายจ่ายอื่น', 'ยจ่ายอิน', '43,256,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 5']
# page: 375, ['level']: 5, xPos: 256.0, text: ['(7)', 'ชุดควบคุมการเคลื่อนที่ภายใต้กล้องจุลทรรศน์', 'ลือนที่ภาย', 'ตำบลโคกเดียน', 'อำเภอเมืองนราธิวาส', 'จังหวัดนราธิวาส', '1', 'ชุด', '2,333,400', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 5']
# page: 406, ['level']: 5, xPos: 218.0, text: ['(7)', 'เครื่องเอกซเรย์เคลื่อนที่ระบบดิจิทัล', 'ตำบลท่าโพธิ์', 'อำเภอเมืองพิษณุโลก', 'จังหวัดพิษณุโลก', '1', 'เครื่อง', '1,300,000', 'บาท']
# No amount found 453 3 ['1.1.2.1', 'ค่าก่อสร้างอาคารการศึกษาและสิ่งก่อสร้างประกอบ', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT']
# No amount found 453 4 ['(1)', 'อาคารศูนย์เรียนรู้พ่อขุนรามคำแหงมหาราช', '(R.U', 'Library', 'and', 'Learning', 'Center)', '5', 'ช้น', '(กอ.)', 'แขวงหัวหมาก', 'เขตบางกะปิ', 'กรุงเทพมหานคร', '1', 'หลัง', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT']
# 🚨 [1] is not 'BULLET':  ['(ุ6)', 'เครื่องให้การรักษาด้วยแสงเลเซอร์แบบคลื่นผสม', 'ตำบลเมืองศรีไค', 'อำเภอวารินชำราบ', 'จังหวัดอุบลราชธานี', '1', 'เครื่อง', '1,700,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['(ุ6)', 'เครื่องให้การรักษาด้วยแสงเลเซอร์แบบคลื่นผสม', 'ตำบลเมืองศรีไค', 'อำเภอวารินชำราบ', 'จังหวัดอุบลราชธานี', '1', 'เครื่อง', '1,700,000', 'บาท'] ['NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND']
# page: 502, ['level']: 5, xPos: 223.0, text: ['(ุ6)', 'เครื่องให้การรักษาด้วยแสงเลเซอร์แบบคลื่นผสม', 'ตำบลเมืองศรีไค', 'อำเภอวารินชำราบ', 'จังหวัดอุบลราชธานี', '1', 'เครื่อง', '1,700,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 5']
# page: 580, ['level']: 5, xPos: 221.0, text: ['(11)', 'ระบบฝึกหุ่นยนต์อัจฉริยะระบบนำทางอัตโนมัติและเรียนรู้การจดจำ', 'แขวงจันทรเกษม', 'เขตจตุจักร', 'กรุงเทพมหานคร', '1', 'ระบบ', '3,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 688, ['level']: 3, xPos: 209.0, text: ['(8)', 'เงินสมทบกองทุนเงินทดแทน', '9,200', 'บาท']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.3(2)', max=352.0, style=ProgressStyle(description_…
# No amount found 82 3 ['1.1.2.1', 'ค่าที่ดินและสิ่งก่อสร้าง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 82 4 ['(1)', 'ก่อสร้างอาคารหอสมุดกลาง', 'ตำบลท่างิ้ว', 'อำเภอเมืองนครศรีธรรมราช', 'จังหวัดนครศรีธรรมราช', '1', 'หลัง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 124, ['level']: 3, xPos: 180.0, text: ['1)', 'เงินอุดหนุนค่าใช้จ่ายโครงการอนุรักษ์พันธุกรรมพืชอันเนื่องมาจากพระราชดำริฯ', '3,843,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 127, ['level']: 3, xPos: 180.0, text: ['1)', 'เงินอุดหนุนค่าใช้จ่ายโครงการยุทธศาสตร์มหาวิทยาลัยราชภัฏเพื่อการพัฒนาท้องถิ่น', '35,533,500', 'บาท']
# No amount found 189 3 ['1.1.2.1', 'ค่าที่ดินและสิ่งก่อสร้าง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 189 4 ['(1)', 'อาคารหอประชุม', 'ตำบลประตูชัย', 'อำเภอพระนครศรีอยุธยา', 'จังหวัดพระนครศรีอยุธยา', '1', 'หลัง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# ['CATEGORY_LV1 is not as descripted']
# page: 296, ['level']: 1, xPos: 123.0, text: ['2.', 'งบดาเนินงาน', '8,232,500', 'บาท']
# 🚨 [1] is not 'BULLET':  ['เงินอุดหนุนค่าใช้จ่ายในการดำเนินโครงการนวัตกรรมการพัฒนา', 'และยกระดับผลิตภัณฑ์ผ้าท้องถิ่นเสริมเศรษฐกิจฐานราก', 'จังหวัดนราธิวาส', '841,400', 'บาท']
# 🚨 bulltet_lebel is -1:  ['เงินอุดหนุนค่าใช้จ่ายในการดำเนินโครงการนวัตกรรมการพัฒนา', 'และยกระดับผลิตภัณฑ์ผ้าท้องถิ่นเสริมเศรษฐกิจฐานราก', 'จังหวัดนราธิวาส', '841,400', 'บาท'] ['NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 323, ['level']: 3, xPos: 260.0, text: ['เงินอุดหนุนค่าใช้จ่ายในการดำเนินโครงการนวัตกรรมการพัฒนา', 'และยกระดับผลิตภัณฑ์ผ้าท้องถิ่นเสริมเศรษฐกิจฐานราก', 'จังหวัดนราธิวาส', '841,400', 'บาท']
# ['CATEGORY_LV1 is not as descripted']
# page: 473, ['level']: 1, xPos: 221.0, text: ['1.1', 'ค่าครุภัณฑ์', 'ที่ดินและสิ่งก่อสร้าง', '32,488,900', 'บาท']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.3(3)', max=396.0, style=ProgressStyle(description_…
# No amount found 225 3 ['1.1.2.1', 'ค่าก่อสร้างอาคารการศึกษาและสิ่งก่อสร้างประกอบ', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT']
# No amount found 225 4 ['(1)', 'อาคารแสดงนิทรรศการและการสอนนั้นทนาการ', 'แขวงทุ่งมหาเมฆ', 'เขตสาทร', 'กรุงเทพมหานคร', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 284 3 ['1.1.2.1', 'ค่าก่อสร้างอาคารการศึกษาและสิ่งก่อสร้างประกอบ', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 284 4 ['(1)', 'ก่อสร้างอาคารเรียนและปฏิบัติการ', 'คณะสถาปัตยกรรมศาสตร์', 'และการออกแบบ', 'ศูนย์พระนครเหนือ', 'แขวงวงศ์สว่าง', 'เขตบางซื่อ', 'กรุงเทพมหานคร', '1', 'หลัง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# [288]
# No amount found 465 4 ['(1)', 'อาคารปฏิบัติการการเรียนการสอนและการวิจัยด้านการเกษตร', 'บาท'] ['BULLET', 'NOTMATCH', 'BAHT']
# No amount found 492 3 ['(1)', 'ก่อสร้างอาคารศูนย์บริการการแพทย์ชั้นเลิศ', 'โรงพยาบาลศรีนครินทร์', 'คณะแพทยศาสตร์', 'ตำบลในเมือง', 'อำเภอเมืองขอนแก่น', 'จังหวัดขอนแก่น', 'บ', 'น', '1', 'รายการ', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.3(4)', max=404.0, style=ProgressStyle(description_…
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 149, ['level']: 3, xPos: 236.0, text: ['1)', 'เงินอุดหนุนโครงการการเสริมสร้างความเข้มแข็งของระบบคุ้มครองทางสังคม', 'สำหรับกลุ่มเปราะบาง', '9,703,400', 'บาท']
# No amount found 175 3 ['(4)', 'อาคารสัมมนา', 'วิทยาเขตอีสาน', 'ตำบลในเมือง', 'อำเภอเมืองขอนแก่น', 'จังหวัดขอนแก่น', '1', 'หลัง', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 192, ['level']: 3, xPos: 181.0, text: ['3)', 'ค่าที่ดิน/สิ่งก่อสร้าง', '177,062,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 192, ['level']: 4, xPos: 201.0, text: ['(1)', 'ค่าที่ดินและสิ่งก่อสร้างที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', 'รวม', '21', 'รายการ', '(รวม', '39', 'หน่วย)', '74,194,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 192, ['level']: 4, xPos: 201.0, text: ['(2)', 'ปรับปรุงอาคารศูนย์วิจัยและพัฒนาวัคซีน', 'ระยะที่', '2', 'สถาบันชีววิทยาศาสตร์โมเลกุล', 'มหาวิทยาลัยมหิดล', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'งาน', '35,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 192, ['level']: 4, xPos: 201.0, text: ['(3)', 'ศูนย์การเรียนรู้งานวิจัยและนวัตกรรมกุ้งและห้องปฏิบัติการ', 'สถาบันชีววิทยาศาสตร์โมเลกุล', 'มหาวิทยาลัยมหิดล', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'งาน', '18,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 192, ['level']: 4, xPos: 201.0, text: ['(4)', 'ปรับปรุงอาคารสถาบันนวัตกรรมการเรียนรู้', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'รายการ', '49,867,300', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 192, ['level']: 3, xPos: 181.0, text: ['4)', 'เงินอุดหนุนเป็นค่าใช้จ่ายโครงการพัฒนากำลังคนด้านวิทยาศาสตร์', 'de', 'ระยะที่', '2', '(ทุนเรียนดีวิทยาศาสตร์แห่งประเทศไทย)', '24,433,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(31)', 'เครื่องอบฆ่าเชื้อด้วยแก๊สเอทธิลีนอ๊อกไซด์', 'ชนิด', '100%', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '3,852,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(32)', 'เครื่องผ่าตัดต้อกระจกด้วยคลื่นเสียงความถี่สูง', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '3,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(33)', 'เครื่องเพิ่มปริมาณสารพันธุกรรมในสภาพจริงพร้อมอุปกรณ์', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,675,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(34)', 'เครื่องช่วยพยุงการทำงานของหัวใจและปอด', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '3,900,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(35)', 'เครื่องติดตามระบบพลศาสตร์การไหลเวียนในร่างกายอย่างต่อเนื่อง', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(36)', 'เครื่องช่วยหายใจชนิดควบคุมปริมาตร', 'ชนิดมีระบบหย่าเครื่องอัตโนมัติ', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,200,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(37)', 'เครื่องไตเทียม', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '2', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(38)', 'เครื่องกระตุกหัวใจแบบ', '2', 'เฟส', 'พร้อมระบบกระตุกหัวใจแบบกึ่งอัตโนมัติ', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(39)', 'เครื่องตรวจสมรรถภาพการทำงานของหัวใจขณะออกกำลังกาย', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,400,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(40)', 'เครื่องปั่นตกตะกอนสารความเร็วสูงพร้อมระบบควบคุมอุณหภูมิ', 'ะ', '๕', 'บาท', 'ชนิดตั้งพื้น', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,200,000']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(41)', 'กล้องจุลทรรศน์ชนิดหัวกลับสำหรับงานวิจัยฟลูออเรสเซนต์', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'กล้อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(42)', 'ชุดแท่นวางตัวอย่างชนิดขับเคลื่อนด้วยมอเตอร์พร้อมอุปกรณ์ประกอบ', 'สำหรับกล้องจุลทรรศน์คอนโฟคอลชนิดเลเซอร์ส่องกราด', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'ชุด', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(43)', 'เครื่องวิเคราะห์นับแยกเซลล์เม็ดเลือดประสิทธิภาพสูง', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '10,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(44)', 'ตู้แช่แข็ง', '-80', 'องศาเซลเซียส', 'ขนาดไม่น้อยกว่า', '810', 'ลิตร', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '3', 'ตู้', '3,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(45)', 'เครื่องวัดค่าการดูดกลืนแสงและเรืองแสงแบบไมโครเพลท', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(46)', 'เครื่องฉาบผิวตัวอย่างด้วยโลหะ', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,060,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(47)', 'เครื่องทำให้ตัวอย่างแห้งที่อุณหภูมิวิกฤตอัตโนมัติ', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,990,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(48)', 'เครื่องวิเคราะห์ปฏิกิริยาการเปล่งแสงด้านภูมิคุ้มกันวิทยาในถาดหลุม', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '6,420,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(49)', 'เครื่องเอกซเรย์ตรวจสวนหัวใจและหลอดเลือดชนิดระนาบเดี่ยว', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '31,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 212, ['level']: 4, xPos: 231.0, text: ['(50)', 'ระบบศูนย์กลางเก็บบันทึกข้อมูลทางสรีรวิทยาของผู้ป่วยฉุกเฉิน', 'ในภาวะวิกฤต', 'พร้อมเครื่องเฝ้าติดตามสัญญาณชีพผู้ป่วยชนิดโมดูล', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'ระบบ', '27,350,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(51)', 'เครื่องตรวจระบบทางเดินอาหารระบบดิจิตอล', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '20,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(52)', 'เครื่องล้างฆ่าเชื่ออัตโนมัติ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '14,445,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(53)', 'เครื่องเอกซเรย์ทั่วไปด้วยระบบดิจิตอล', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '14,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(54)', 'เครื่องช่วยผ่าตัดน้ำวิถีด้วยระบบคอมพิวเตอร์โดยใช้ระบบแม่เหล็กไฟฟ้า', 'บนแผ่นรองศีรษะ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '7,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(55)', 'เครื่องมือส่องกล้องทางเดินอาหารด้วยกำลังขยายสูง', '520', 'เท่า', 'พร้อมอุปกรณ์', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '6,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(56)', 'เครื่องยกตัวและเคลื่อนย้ายผู้ป่วยชนิดราง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(57)', 'เครื่องดูดสลายเนื้องอกด้วยคลื่นความถี่สูง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(58)', 'เครื่องกระตุกหัวใจด้วยไฟฟ้า', 'ชนิด', '2', 'เฟส', 'พร้อมแสดงคุณภาพ', 'ของการกดหน้าอกและภาคควบคุมจังหวะการเต้นของหัวใจ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(59)', 'เครื่องหัวใจและปอดเทียม', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '6,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(60)', 'เครื่องเฝ้าระวัง/ติดตามการทำงานของระบบไหลเวียนแบบซับซ้อน', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,300,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(61)', 'ชุดเครื่องมือผ่าตัดหัวใจและหลอดเลือด', 'พร้อมอุปกรณ์', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'ชุด', '4,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(62)', 'เครื่องย้อมสีทางพยาธิวิทยาอัตโนมัติ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '17,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(63)', 'เครื่องเตรียมเนื้อเยื่ออัต', 'โนมัติปราศจากสารไซลีน', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '2', 'เครื่อง', '2,800,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(64)', 'กล้องสิบคนดูพร้อมจอ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,400,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(65)', 'กล้องจุลทรรศน์ฟลูออเรสเซนต์', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'กล้อง', '1,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(66)', 'เครื่องเพิ่มอุณหภูมิของเหลวส่งถ่ายผู้ป่วย', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(67)', 'กล้องส่องตรวจและผ่าตัดระบบวีดีทัศน์ชนิดสร้างภาพด้วยการเปล่งแสง', 'ฟลูออเรสเซนต์ความละเอียด', '4', 'เค', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'กล้อง', '8,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(68)', 'เครื่องตรวจอวัยวะภายในด้วยคลื่นเสียงความถี่สูง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 213, ['level']: 4, xPos: 231.0, text: ['(69)', 'เครื่องวัดปริมาณออกซิเจนในกล้ามเนื้อ', 'และเนื่อเยื่อของคน', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(70)', 'เครื่องมือทำหัตถการปลูกถ่ายผิวหนังด้วยวิธีตัดแบบตาราง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(71)', 'เครื่องมือเปิดกะโหลกศีรษะพร้อมอุปกรณ์', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '14,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(72)', 'เตียงผ่าตัดใหญ่พร้อมอุปกรณ์ดึงรังกระดูกและข้อ', 'าติด', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เตียง', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(73)', 'เตียงผ่าตัดผู้ป่วยกระดูกสันหลังชนิดหมุนพื้นเตียง', '360', 'องศา', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เตียง', '6,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(74)', 'เครื่องควบคุมอุณหภูมิร่างกาย', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '2', 'เครื่อง', '2,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(75)', 'เครื่องช่วยหายใจเด็กชนิดควบคุมความดันและปริมาตรพร้อม', 'ชนิดความถี่สูง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '5', 'เครื่อง', '10,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(76)', 'ตู้อบเด็กชนิดควบคุมอุณหภูมิพร้อมปรับเปลี่ยนให้เป็นเครื่อง', 'ให้ความอบอุ่นทารกแรกเกิดพร้อมชุดชั่งน้ำหนัก', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '5', 'ตู้', 'บ', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(77)', 'เครื่องวัดปริมาณความอิ่มตัวของออกซิเจนในสมอง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(78)', 'เครื่องควบคุมการจ่ายก๊าซไนตริกออกไซด์แบบอัตโนมัติพร้อมมอนิเตอร์', 'แสดงผล', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,200,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(79)', 'เครื่องช่วยทดแทนการทำงานของไตชนิดต่อเนื่อง', 'ก่อเนื่อง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(80)', 'เครื่องมือผ่าตัด', 'พร้อมอุปกรณ์ประกอบ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '3', 'เครื่อง', '3,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(81)', 'เครื่องติดตามการทำงานของหัวใจและสัญญาณชีพอัตโนมัติ', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '10', 'เครือง', '12,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(82)', 'เครื่องตรวจอวัยวะภายในด้วยคลื่นเสียงความถี่สูง', 'พร้อมชุดหัวตรวจ', 'หัวใจ', 'หลอดเลือด', 'และช่องท้อง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '4,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(83)', 'เครื่องถ่างกล้ามเนื้อชนิดถ่างขยายผ่าตัดช่องท้อง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '2', 'เครื่อง', '4,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(84)', 'อุปกรณ์เครื่องจีปิดและตัดเส้นเลือด', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '1,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(85)', 'เครื่องกระตุ้นสมอง', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'เครื่อง', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(86)', 'ชุดเลี้ยงเซลล์แบบถุงในสภาวะควบคุมขนาด', '0.3-25', 'ลิตร', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '2', 'ชุด', '9,795,400', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(87)', 'ตู้เก็บตัวอย่างชนิดควบคุมอุณหภูมิ', '-80', 'องศาเซลเซียส', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '2', 'ตู้', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 214, ['level']: 4, xPos: 231.0, text: ['(88)', 'เครื่องถ่ายภาพเอกซเรย์คอมพิวเตอร์สามมิติระดับนาโนสเกล', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '35,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(89)', 'เครื่องตรวจวิเคราะห์ดีเอ็นเอด้วยเทคนิคมัลดิทอฟ', '6d', '๘', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '12,840,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(90)', 'เครื่องวิเคราะห์การตอบสนองภูมิคุ้มกัน', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '5,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(91)', 'กล้องจุลทรรศน์แรงอะตอม', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'กล้อง', '14,980,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(92)', 'เครื่องตรวจวัดและวิเคราะห์สารชีวโมเลกุลด้วยแสงฟลูออเรสเซนต์', 'และเคมิลูมิเนสเซนส์', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(93)', 'เครื่องผลิตวัคซีนและทำวัคซีนให้บริสุทธิ์', 'พร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '27,672,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(94)', 'เครื่องวิเคราะห์หาหมู่ฟังก์ชั่นทางเคมีด้วยช่วงแสงอินฟราเรด', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(95)', 'เครื่องดูดจ่ายสารอัตโนมัติสำหรับเครื่องเซอร์คูลาร์ไตโครอิก', 'พร้อมโปรแกรมวิเคราะห์', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(96)', 'เครื่องถ่ายภาพรังสีนอกปากระบบดิจิทัล', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,428,900', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(97)', 'กล้องจุลทรรศน์สำหรับงานรักษาคลองรากฟัน', 'พร้อมชุดถ่ายภาพ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'กล้อง', '2,200,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(98)', 'ระบบรางขนส่งสิ่งส่งตรวจพร้อมติดตั้ง', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '2,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(99)', 'เครื่องติดฉลากเพื่อจำแนกสิ่งส่งตรวจแบบอัตโนมัติชนิดเคลื่อนที่', 'พร้อมระบบจัดการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '1,134,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(100)', 'เตียงผ่าตัด', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '3', 'เตียง', '9,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(101)', 'เครื่องจี้และตัดด้วยก๊าซอาร์กอน', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,900,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(102)', 'เครื่องให้การรักษาด้วยคลื่นกระแทกชนิดโฟกัสและเรเดียล', 'พร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '3,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(103)', 'กล้องส่องตรวจลำไส้ใหญ่สำหรับทำหัตถการ', 'ชนิดให้ภาพ', 'ความละเอียดสูง', 'สายส่องตรวจขนาดเล็ก', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'กล้อง', '2,230,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(104)', 'เครื่องมือผ่าตัดกระดูกสันหลังผ่านท่อพร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ชุด', '1,184,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(105)', 'เครื่องตรวจอวัยวะภายในด้วยคลื่นเสียงความถี่สูง', 'ชนิดหิ้วถือ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 215, ['level']: 4, xPos: 231.0, text: ['(106)', 'เครื่องเลเซอร์สำหรับกรอผิว', 'รักษาหลุมสิวและรอยแผลเป็น', 'พร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'รายการ', '3,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(107)', 'เครื่องฉายแสงรักษาโรคผิวหนัง', 'พร้อมซอฟต์แวร์สำหรับควบคุม', 'การทำงาน', 'พร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'รายการ', '1,800,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(108)', 'เครื่องผ่าตัดน้ำวุ้นลูกตาส่วนหลังพร้อมเลเซอร์และผ่าตัด', 'สลายตัวต้อกระจก', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '4,640,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(109)', 'เครื่องตรวจคลื่นสมองด้วยไฟฟ้า', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '2,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(110)', 'ชุดกล้องส่องตรวจทางเดินนำดีชนิดวิดีทัศน์', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ชุด', '1,900,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(112)', 'เครื่องตรวจอวัยวะภายในด้วยคลื่นเสียงความถี่สูงชนิดสี', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '4,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(113)', 'เครื่องเอกซเรย์ดิจิตอล', 'ชนิด', 'ดี', 'อาร์', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '13,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(114)', 'เครื่องย่อยตัวอย่างโดยใช้แหล่งพลังงานจากคลื่นไมโครเวฟ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '1,979,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(115)', 'เครื่องวัดปริมาณสารอินทรีย์ในน้ำพร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '3,038,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(116)', 'เครื่องอ่านปฏิกิริยาบนไมโครเพลทพร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '2,800,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(117)', 'เครื่องเพิ่มปริมาณสารพันธุกรรมพร้อมระบบตรวจวัดในสภาพจริง', 'พร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '3,210,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(118)', 'ถังผสมด้วยแรงแม่เหล็กไฟฟ้าแบบมีแจ็คเก็ต', 'ขนาด', '200', 'ลิตร', 'พร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '6,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(119)', 'ระบบการทำให้ปราศจากเชื้อด้วยไอน้ำสำหรับเครื่องทำเข้มข้นผลิตภัณฑ์', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'งาน', '2,700,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(120)', 'โครงสำหรับถุงผสมด้วยแรงแม่เหล็กไฟฟ้าแบบมีแจ็คเก็ต', 'เกต', 'ขนาด', '200', 'ลิตร', 'พร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '11,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(121)', 'รถเข็นสำหรับขนย้ายอุปกรณ์แบบมีชุดจ่ายลมสะอาด', 'ระดับ', '100', '(มีแบตเตอรี่ในตัว)', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '2', 'คัน', '8,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(122)', 'เครื่องทดสอบตัวกรอง', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '1,100,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 216, ['level']: 4, xPos: 231.0, text: ['(123)', 'เครื่องปิดฝาขวดบรรจุยาฉีด', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'เครื่อง', '13,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(124)', 'ตู้เตรียมยาเคมีบำบัดสำหรับงานบรรจุ', 'พร้อมระบบฆ่าเชื้อ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '2,700,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(125)', 'เครื่องบรรจุของเหลวใส่ถุงพร้อมอุปกรณ์ประกอบ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ชุด', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(126)', 'เครื่องบันทึกข้อมูล', 'พร้อมระบบปฏิบัติการ', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'ระบบ', '1,010,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(127)', 'วงจรระบบจ่ายนำเพิ่มเติมสำหรับ', 'นำบริสุทธิ์', '(Purified', 'water,', 'PW)', 'และนำกลั่น', '(Water', 'for', 'injection,', 'WFI)', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '1', 'งาน', '20,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(128)', 'เครื่องเอกซเรย์ฟลูออโรสโคปเคลื่อนที่แบบ', 'ซี-อาร์ม', 'ชุดรับภาพ', 'ชนิดแฟลตพาแนล', 'ขนาดไม่น้อยกว่า', '20', 'กิโลวัตต์', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เครื่อง', '8,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(129)', 'เครื่องเอกซเรย์เคลื่อนที่ระบบดิจิตอล', '(', 'Portable', 'X-ray', ')', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เครื่อง', '6,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(130)', 'โต๊ะเครื่องมือตรวจทางหู', 'คอ', 'จมูก', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'โต๊ะ', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(131)', 'กล้องจุลทรรศน์ส่องตรวจทางหู', 'คอ', 'จมูก', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'กล้อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(132)', 'เครื่องช่วยใส่ท่อหายใจชนิดวีดีทัศน์สำหรับงานวิสัญญี', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เครื่อง', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(133)', 'เครื่องมือผ่าตัดสแตนเลสสำหรับศัลยกรรมตกแต่ง', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'รายการ', '1,500,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(134)', 'เครื่องมอเตอร์ไฟฟ้าสำหรับตัด', 'กรอกระดูก', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '2', 'เครื่อง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(135)', 'สว่านเจาะกระดูกชนิดเปลี่ยนหัวได้', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'ตัว', '1,970,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(136)', 'สู่วิ่งสำหรับวิเคราะห์การเดินและแรงกดเท้า', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'ตัว', '5,800,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(137)', 'เครื่องตรวจวิเคราะห์หาสารชีวเคมีในเลือดอัตโนมัติ', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เครื่อง', '6,600,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(138)', 'เครื่องออกกำลังกายและบริหารกล้ามเนื้อระบบดิจิตอล', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เค่', 'เครื่อง', '3,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(139)', 'เครื่องตรวจวิเคราะห์ด้านการแข็งตัวของเลือดอัตโนมัติ', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เครื่อง', '2,300,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(140)', 'เตียงผ่าตัดศัลยกรรมระบบไฟฟ้าควบคุมการทำงานด้วยรีโมทคอนโทรล', 'พร้อมอุปกรณ์', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'เตียง', '2,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 217, ['level']: 4, xPos: 231.0, text: ['(141)', 'เครื่องวิเคราะห์สารสำคัญในกัญชาแบบโครมาโตรกราฟฟีของเหลว', 'แขวงทุ่งพญาไท', 'เขตราชเทวี', 'กรุงเทพมหานคร', '1', 'เครื่อง', '2,700,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 218, ['level']: 4, xPos: 231.0, text: ['(2)', 'ปรับปรุงห้องปฏิบัติการเสมือนจริงเพื่อการเรียนรู้ด้านการผลิต', 'และพัฒนาชีววัตถุและวัคซีน', 'ตำบลศาลายา', 'อำเภอพุทธมณฑล', 'จังหวัดนครปฐม', '2', 'ห้อง', '26,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 218, ['level']: 4, xPos: 231.0, text: ['(3)', 'โครงการปรับปรุงงานเปลี่ยนอวัยวะศิริราช', 'ตึก', '84', 'ปี', 'ชั้น', '1', 'และชั้น', '2', 'แขวงศิริราช', 'เขตบางกอกน้อย', 'กรุงเทพมหานคร', '1', 'งาน', '43,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 218, ['level']: 4, xPos: 231.0, text: ['(4)', 'ก่อสร้างถนนผิวจราจรแอสพัลท์ติกคอนกรีต', 'โครงการจัดตั้ง', 'วิทยาเขตนครสวรรค์', 'มหาวิทยาลัยมหิดล', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'รายการ', '22,000,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 218, ['level']: 4, xPos: 231.0, text: ['(5)', 'ระบบเปลี่ยนพลังงานแสงอาทิตย์เป็นพลังไฟฟ้าบนหลังคาศูนย์การแพทย์', 'มหิดลบำรุงรักษ์', 'จังหวัดนครสวรรค์', 'ตำบลเขาทอง', 'อำเภอพยุหะคีรี', 'จังหวัดนครสวรรค์', '1', 'รายการ', '10,610,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# ...
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 247, ['level']: 4, xPos: 220.0, text: ['(14)', 'เงินอุดหนุนสำหรับการดำเนินงานตามแนวทางโครงการพระราชดำริ', 'ด้านสาธารณสุข', '360,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 247, ['level']: 4, xPos: 220.0, text: ['(15)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารเสริม', '(นม)', '7,103,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 254, ['level']: 4, xPos: 274.0, text: ['(44)', 'ค่าอุปกรณ์การเรียน', '13,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 390, ['level']: 4, xPos: 278.0, text: ['(14)', 'ค่าอุปกรณ์การเรียน', '30,400', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 415, ['level']: 3, xPos: 155.0, text: ['3)', 'เงินอุดหนุนดำเนินการตามอำนาจหน้าที่และภารกิจถ่ายโอน', '13,716,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 415, ['level']: 2, xPos: 139.0, text: ['1.2', 'เงินอุดหนุนเฉพาะกิจ', '8,426,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 415, ['level']: 3, xPos: 156.0, text: ['1)', 'ค่าครุภัณฑ์', '8,426,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 415, ['level']: 4, xPos: 192.0, text: ['(1)', 'ครุภัณฑ์อื่น', 'ๆ', 'ที่มีราคาต่อหน่วยต่ำกว่า', '1', 'ล้านบาท', '8,426,200', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '28', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 462, ['level']: 4, xPos: 253.0, text: ['(8)', 'เงินอุดหนุนสำหรับการดำเนินงานตามแนวทางโครงการพระราชดำริ', 'ด้านสาธารณสุข', '280,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 462, ['level']: 4, xPos: 253.0, text: ['(9)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารเสริม', '(นม)', '2,025,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 638, ['level']: 4, xPos: 253.0, text: ['(8)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารกลางวัน', '6,341,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 638, ['level']: 4, xPos: 253.0, text: ['(9)', 'ะ', '4้', 'เงินอุดหนุนสำหรับการจัดการศึกษาตั้งแต่ระดับอนุบาลจนจบการศึกษา', 'ขั้นพื้นฐาน', '2,214,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 638, ['level']: 5, xPos: 276.0, text: ['(9.1)', 'ค่าจัดการเรียนการสอน', '1,158,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 638, ['level']: 5, xPos: 276.0, text: ['(9.2)', 'ค่าเครื่องแบบนักเรียน', '220,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 638, ['level']: 5, xPos: 276.0, text: ['(9.3)', 'ค่าหนังสือเรียน', '342,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 638, ['level']: 5, xPos: 276.0, text: ['(9.4)', 'ค่าอุปกรณ์การเรียน', '201,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 638, ['level']: 5, xPos: 276.0, text: ['(9.5)', 'ค่ากิจกรรมพัฒนาคุณภาพผู้เรียน', '292,700', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 638, ['level']: 4, xPos: 253.0, text: ['(10)', 'เงินอุดหนุนสำหรับขับเคลื่อนโครงการสัตว์ปลอดโรค', 'คนปลอดภัย', 'จากโรคพิษสุนัขบ้า', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้า', 'น้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '69,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 638, ['level']: 4, xPos: 252.0, text: ['(11)', 'เงินอุดหนุนสำหรับสำรวจข้อมูลจํานวนสัตว์และขึ้นทะเบียนสัตว์', 'ตามโครงการสัตว์ปลอดโรค', 'คนปลอดภัยจากโรคพิษสุนัขบ้า', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้าน้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '13,900', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 639, ['level']: 4, xPos: 253.0, text: ['(12)', 'เงินอุดหนุนสำหรับการดำเนินงานตามแนวทางโครงการพระราชดำริ', 'ด้านสาธารณสุข', '380,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 639, ['level']: 4, xPos: 253.0, text: ['(13)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารเสริม', '(นม)', '2,863,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 687, ['level']: 4, xPos: 213.0, text: ['(12)', 'เงินอุดหนุนสำหรับขับเคลื่อนโครงการสัตว์ปลอดโรค', 'คนปลอดภัย', 'จากโรคพิษสุนัขบ้า', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้า', 'น้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '60,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 687, ['level']: 4, xPos: 213.0, text: ['(13)', 'เงินอุดหนุนสำหรับสำรวจข้อมูลจำนวนสัตว์และขึ้นทะเบียนสัตว์', 'ตามโครงการสัตว์ปลอดโรค', 'คนปลอดภัยจากโรคพิษสุนัขบ้า', 'บ', 'บ', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้าน้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '6,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 687, ['level']: 4, xPos: 213.0, text: ['(14)', 'เงินอุดหนุนสำหรับการดำเนินงานตามแนวทางโครงการพระราชดำริ', 'ด้านสาธารณสุข', '700,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 687, ['level']: 4, xPos: 213.0, text: ['(15)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารเสริม', '(นม)', '15,793,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 687, ['level']: 3, xPos: 159.0, text: ['3)', 'เงินอุดหนุนตำเนินการตามอำนาจหน้าที่และภารกิจถ่ายโอน', '15,048,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 1, by pattern 2']
# page: 687, ['level']: 2, xPos: 142.0, text: ['1.2', 'เงินอุดหนุนเฉพาะกิจ', '6,741,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 687, ['level']: 3, xPos: 159.0, text: ['1)', 'ค่าครุภัณฑ์', '2,584,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 687, ['level']: 4, xPos: 195.0, text: ['(1)', 'ครุภัณฑ์การศึกษาที่มีราคาต่อหน่วยต่ำกว่า', '1', 'ล้านบาท', '184,200', 'บาท', 'รวม', '6', 'รายการ', '(รวม', '6', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 687, ['level']: 4, xPos: 195.0, text: ['(2)', 'รถบรรทุกขยะ', 'ขนาด', '6', 'ตัน', '6', 'ล้อ', 'ปริมาตรกระบอกสูบไม่ต่ำกว่า', '6,000', 'ซีซี', 'หรือกำลังเครื่องยนต์สูงสุดไม่ต่ำกว่า', '170', 'กิโลวัตต์', 'แบบอัตท้าย', 'ตำบลหน้าเมือง', 'อำเภอเมืองราชบุรี', 'จังหวัดราชบุรี', '1', 'คัน', '2,400,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 2, by pattern 3']
# page: 687, ['level']: 3, xPos: 158.0, text: ['2)', 'ค่าที่ดิน/สิ่งก่อสร้าง', '4,157,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 687, ['level']: 4, xPos: 195.0, text: ['(1)', 'ค่าก่อสร้างระบบสาธารณูปโภคที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '4,157,000', 'บาท', 'รวม', '3', 'รายการ', '(รวม', '3', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 814, ['level']: 4, xPos: 276.0, text: ['(44)', 'ค่าอุปกรณ์การเรียน', '88,600', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 822, ['level']: 4, xPos: 252.0, text: ['(8)', 'เงินอุดหนุนสำหรับสนับสนุนค่าใช้จ่ายในการจัดการศึกษา', 'สำหรับศูนย์พัฒนาเด็กเล็ก', '330,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(8.1)', 'ค่าจัดการเรียนการสอน', '262,300', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(8.2)', 'ค่าเครื่องแบบนักเรียน', '18,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(8.3)', 'ค่าหนังสือเรียน', '12,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(8.4)', 'ค่าอุปกรณ์การเรียน', '12,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(8.5)', 'ค่ากิจกรรมพัฒนาคุณภาพผู้เรียน', 'บd', '25,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 822, ['level']: 4, xPos: 253.0, text: ['(9)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารกลางวัน', '4,510,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 822, ['level']: 4, xPos: 253.0, text: ['(10)', 'เงินอุดหนุนสำหรับการจัดการศึกษาตั้งแต่ระดับอนุบาล', 'จนจบการศึกษาชั้นพื้นฐาน', '2,146,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(10.1)', 'ค่าจัดการเรียนการสอน', '1,127,800', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(10.2)', 'ค่าเครื่องแบบนักเรียน', '213,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(10.3)', 'ค่าหนังสือเรียน', 'บ', '4', 'ส', '326,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(10.4)', 'ค่าอุปกรณ์การเรียน', '194,200', 'บาท']
# ['LEVEL NOT MATCH level: by x position 6, by pattern 5']
# page: 822, ['level']: 5, xPos: 276.0, text: ['(10.5)', 'ค่ากิจกรรมพัฒนาคุณภาพผู้เรียน', 'บส่', '285,100', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 822, ['level']: 4, xPos: 252.0, text: ['(11)', 'เงินอุดหนุนสำหรับขับเคลื่อนโครงการสัตว์ปลอดโรค', 'คนปลอดภัย', 'จากโรคพิษสุนัขบ้า', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้า', 'น้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '90,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 823, ['level']: 4, xPos: 253.0, text: ['(12)', 'เงินอุดหนุนสำหรับสำรวจข้อมูลจำนวนสัตว์และขึ้นทะเบียนสัตว์', 'ตามโครงการสัตว์ปลอดโรค', 'คนปลอดภัยจากโรคพิษสุนัขบ้า', 'ตามพระปณิธาน', 'ศาสตราจารย์', 'ดร.', 'สมเด็จพระเจ้าน้องนางเธอ', 'เจ้าฟ้าจุฬาภรณวลัยลักษณ์', 'อัครราชกุมารี', 'กรมพระศรีสวางควัฒน', 'วรขัตติยราชนารี', '18,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 823, ['level']: 4, xPos: 253.0, text: ['(13)', 'เงินอุดหนุนสำหรับการดำเนินงานตามแนวทางโครงการพระราชดำริ', 'ด้านสาธารณสุข', '200,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 823, ['level']: 4, xPos: 253.0, text: ['(14)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารเสริม', '(นม)', '2,000,600', 'บาท']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.16(3)', max=326.0, style=ProgressStyle(description…
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '5,896,900', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '5,896,900', 'บาท'] ['NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 71, ['level']: 3, xPos: 186.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '5,896,900', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 102, ['level']: 4, xPos: 240.0, text: ['(11)', 'เงินอุดหนุนสำหรับสนับสนุนอาหารกลางวัน', '6,813,500', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 111, ['level']: 4, xPos: 230.0, text: ['(2)', 'ค่าก่อสร้างอื่นๆที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '5,893,400', 'บาท', 'รวม', '2', 'รายการ', '(รวม', '2', 'หน่วย)']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '10,044,800', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '10,044,800', 'บาท'] ['NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND']
# page: 119, ['level']: 4, xPos: 206.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '10,044,800', 'บาท']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '23,196,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '23,196,000', 'บาท'] ['NOTMATCH', 'NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 167, ['level']: 3, xPos: 178.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '23,196,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 263, ['level']: 4, xPos: 224.0, text: ['(2)', 'ค่าปรับปรุงทางและสะพานที่มีราคาต่อหน่วยตำกว่า', '10', 'ล้านบาท', '2,966,000', 'บาท', 'รวม', '2', 'รายการ', '(รวม', '2', 'หน่วย)']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '3,880,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '3,880,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)'] ['NOTMATCH', 'AMOUNT', 'BAHT', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 439, ['level']: 4, xPos: 211.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '3,880,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '11,281,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '11,281,000', 'บาท'] ['NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND']
# page: 479, ['level']: 4, xPos: 210.5, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '11,281,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 479, ['level']: 4, xPos: 230.0, text: ['(1)', 'ค่าก่อสร้างทางและสะพานที่มีราคาต่อหน่วยตำกว่า', '10', 'ล้านบาท', '11,281,000', 'บาท', 'รวม', '3', 'รายการ', '(รวม', '3', 'หน่วย)']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '7,877,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '7,877,000', 'บาท'] ['NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 3, by pattern 4']
# page: 719, ['level']: 3, xPos: 178.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '7,877,000', 'บาท']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '3,932,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '3,932,000', 'บาท'] ['NOTMATCH', 'NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND']
# page: 727, ['level']: 4, xPos: 205.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', 'de', '3,932,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 727, ['level']: 4, xPos: 224.0, text: ['(1)', 'ค่าก่อสร้างทางและสะพานที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '2,381,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 727, ['level']: 4, xPos: 224.0, text: ['(2)', 'ค่าก่อสร้างอื่นๆที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '1,551,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# 🚨 [1] is not 'BULLET':  ['ค่าที่ดิน/สิ่งก่อสร้าง', '8,400,000', 'บาท']
# 🚨 bulltet_lebel is -1:  ['ค่าที่ดิน/สิ่งก่อสร้าง', '8,400,000', 'บาท'] ['NOTMATCH', 'AMOUNT', 'BAHT']
# ['NO BULLET FOUND', 'LEVEL NOT MATCH level: by x position 3, by pattern 2']
# page: 815, ['level']: 3, xPos: 183.0, text: ['ค่าที่ดิน/สิ่งก่อสร้าง', '8,400,000', 'บาท']
# ['LEVEL NOT MATCH level: by x position 4, by pattern 3']
# page: 815, ['level']: 3, xPos: 230.0, text: ['(1)', 'ค่าก่อสร้างอื่นๆที่มีราคาต่อหน่วยต่ำกว่า', '10', 'ล้านบาท', '8,400,000', 'บาท', 'รวม', '1', 'รายการ', '(รวม', '1', 'หน่วย)']
# ['LEVEL NOT MATCH level: by x position 5, by pattern 4']
# page: 823, ['level']: 4, xPos: 230.0, text: ['(2)', 'ค่าปรับปรุงทางและสะพานที่มีราคาต่อหน่วยตำกว่า', '10', 'ล้านบาท', '2,960,000', 'บาท', 'รวม', 'รายการ', 'หน่วย)']
# HBox(children=(FloatProgress(value=0.0, description='2022.3.17', max=42.0, style=ProgressStyle(description_wid…
# No amount found 51 3 ['(3)', 'ปรับปรุงอาคารนวมินทราชินีและอาคารคัคณางค์', 'แขวงปทุมวัน', 'เขตปทุมวัน', 'กรุงเทพมหานคร', '1', 'งาน', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 51 5 ['(5.2)', 'ค่าควบคุมงานก่อสร้างทางเดินเชื่อม', 'ระยะที่', '3', 'แขวงปทุมวัน', 'บ', 'น', 'เขตปทุมวัน', 'กรุงเทพมหานคร', '1', 'งาน', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']
# No amount found 54 3 ['(22)', 'ก่อสร้างทางเดินเชื่อม', 'ระยะที่', '3', 'แขวงปทุมวัน', 'เขตปทุมวัน', 'กรุงเทพมหานคร', '1', 'งาน', '-', 'บาท'] ['BULLET', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'NOTMATCH', 'BAHT', 'BAHT']

# %%
curr_doc = tbg.get_doc('2022.3.1')
df = get_data_frame(curr_doc, True)

# %%
a = clean_entry([curr_doc.page(i, True) for i in [88, 89, 90]], pl=1)
a = get_entry(a)

# %%
df = pd.DataFrame(columns=cols)
for file in onlyfiles:
    new_row = pd.read_csv(mypath + file)
    df = df.append(new_row, ignore_index=True)

# %%
page = curr_doc.page(89	, 1)
print(page.whpage)
xposl, textl = page.xpos_text_lines()
for xpos, line in zip(xposl, textl):
    # print([(txt) for x, txt in zip(xpos.tolist(), line)])
    # print([(txt, x[1]) for x, txt in zip(xpos.tolist(), line)])
    print([(txt, x[0][0]) for x, txt in zip(xpos.tolist(), line)])

# %%
df.loc[df['REF_PAGE_NO'] == 103]

# %%
df.loc[df['REF_DOC'] == '2022.3.1']

# %%
df.loc[df['DEBUG_LOG'] != ''].head(10)
